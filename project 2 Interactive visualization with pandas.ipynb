# %%
import pandas as pd
import cufflinks as cf
import plotly.express as px
from IPython.display import display, HTML

cf.set_config_file(sharing='public',theme='ggplot',offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %%
# read csv file
df_population_row = pd.read_csv('population.csv')
# droping a null value
df_population_row.dropna(inplace=True)
# making a pivot table
df_pivot = df_population_row.pivot(index='Year',
                                    columns='Country Name',
                                    values='Value')
# selecting some contries
df_pivot = df_pivot[['India','China','Andorra','Afghanistan','Viet Nam']]
#show pivot 
df_pivot
# Out:
# Country Name         India         China  Andorra  Afghanistan     Viet Nam
# Year
# 1960          4.359903e+08  6.670700e+08   9510.0    9035043.0   32531933.0
# 1961          4.465647e+08  6.603300e+08  10283.0    9214083.0   33409059.0
# 1962          4.572831e+08  6.657700e+08  11086.0    9404406.0   34288560.0
# 1963          4.681386e+08  6.823350e+08  11915.0    9604487.0   35249101.0
# 1964          4.792296e+08  6.983550e+08  12764.0    9814318.0   36201563.0
# ...                    ...           ...      ...          ...          ...
# 2020          1.402618e+09  1.411100e+09  77380.0   39068979.0   98079191.0
# 2021          1.414204e+09  1.412360e+09  78364.0   40000412.0   98935098.0
# 2022          1.425423e+09  1.412175e+09  79705.0   40578842.0   99680655.0
# 2023          1.438070e+09  1.410710e+09  80856.0   41454761.0  100352192.0
# 2024          1.450936e+09  1.408975e+09  81938.0   42647492.0  100987686.0
#
# [65 rows x 5 columns]

# %% [markdown]
# # 1 LinePlot

# %%
px.line(df_pivot)

# %% [markdown]
# # 2 Barplot

# %%
# selecting only one year (2024)
df_pivot_2024 = df_pivot[df_pivot.index.isin([2024])]
df_pivot_2024
# Out:
# Country Name         India         China  Andorra  Afghanistan     Viet Nam
# Year
# 2024          1.450936e+09  1.408975e+09  81938.0   42647492.0  100987686.0

# %%
# Transpose dataframe from rows to columns or viceversa
df_pivot_2024 = df_pivot_2024.T

# %%
px.bar(df_pivot_2024)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="1a12d8b2-247f-4314-b522-77085ca73270" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1a12d8b2-247f-4314-b522-77085ca73270")) {                    Plotly.newPlot(                        "1a12d8b2-247f-4314-b522-77085ca73270",                        [{"hovertemplate":"Year=2024\u003cbr\u003eCountry Name=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2024","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2024","orientation":"v","showlegend":true,"textposition":"auto","x":["India","China","Andorra","Afghanistan","Viet Nam"],"xaxis":"x","y":{"dtype":"f8","bdata":"AADAe+Ge1UEAAAAm0P7UQQAAAAAgAfRAAAAAIP5VhEEAAACYzBOYQQ=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scatte ...

# %% [markdown]
# # Barplot grouped by "n" varbiles

# %%
# selecting a few year
df_pivot_sample = df_pivot[df_pivot.index.isin([1974,1984,1994,2004,2014,2024])]

# %%
# Transpose dataframe from rows to columns or viceversa
df_pivot_sample = df_pivot_sample.T

# %%
px.bar(df_pivot_sample)

# %% [markdown]
# # Pipchart

# %%
# changing columns names
df_pivot_2024.rename(columns={2024:'2024'},inplace=True)

# %%
df_pivot_2024 = df_pivot_2024.reset_index()

# %%
px.pie(df_pivot_2024,values='2024')

# %% [markdown]
# # Boxplot

# %%
px.box(df_pivot['India'])

# %%
px.box(df_pivot)

# %% [markdown]
# # 5 Histogram

# %%
px.histogram(df_pivot[['India','China']])

# %% [markdown]
# # 6 scatterplot

# %%
px.scatter(df_pivot)
